# %%
import pandas as pd

# %%
df = pd.read_csv('insurance_data.csv',index_col = False)
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
df.columns
# Out:
# Index(['age', 'bought_insurance'], dtype='object')

# %%
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# %%
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
from matplotlib import pyplot as plt

# %%
plt.scatter(df['age'],df['bought_insurance'])
plt.xlabel('age')
plt.ylabel('insurance')
plt.show()

# %%
x = df.drop('bought_insurance',axis = 1)
y = df['bought_insurance']

# %%
x
# Out:
#     age
# 0    22
# 1    25
# 2    47
# 3    52
# 4    46
# 5    56
# 6    55
# 7    60
# 8    62
# 9    61
# 10   18
# 11   28
# 12   27
# 13   29
# 14   49
# 15   55
# 16   25
# 17   58
# 18   19
# 19   18
# 20   21
# 21   26
# 22   40
# 23   45
# 24   50
# 25   54
# 26   23

# %%
y
# Out:
# 0     0
# 1     0
# 2     1
# 3     0
# 4     1
# 5     1
# 6     0
# 7     1
# 8     1
# 9     1
# 10    0
# 11    0
# 12    0
# 13    0
# 14    1
# 15    1
# 16    1
# 17    1
# 18    0
# 19    0
# 20    0
# 21    0
# 22    1
# 23    1
# 24    1
# 25    1
# 26    0
# Name: bought_insurance, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2)

# %%
x_train.shape
# Out:
# (21, 1)

# %%
y_train.shape
# Out:
# (21,)

# %%
x_test.shape
# Out:
# (6, 1)

# %%
y_test.shape
# Out:
# (6,)

# %%
from sklearn.linear_model import LogisticRegression

# %%
x_test
# Out:
#     age
# 25   54
# 1    25
# 14   49
# 4    46
# 21   26
# 11   28

# %%
model = LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
model.predict(x_test)
# Out:
# array([1, 0, 1, 1, 0, 0])

# %%
model.score(x_test,y_test)
# Out:
# 1.0

# %%
model.predict([[41]])
# Out:
# C:\Users\Asad Computers\PycharmProjects\My_Project\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])
